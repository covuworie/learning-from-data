# %%
import numpy as np
import random as rd

# %%
class RandomPoint:
    """ RandomPoint class for representing and manipulating random n-dimensional coordinates. """
    
    def __init__(self, dim=1, lower=0.0, upper=1.0):
        """ Create a new random point assuming a uniform distribution between the upper and lower bounds. 
        Args:
        dim (int): Dimension.
        lower (float): Lower bound.
        upper (float): Upper bound.
        """
        self.dim = dim # dimension
        self.lower = lower # lower bound
        self.upper = upper # upper bound
        self.point = np.random.uniform(lower, upper, dim) # point (numpy.ndarray) (half open interval!)

# %%
class RandomLine:
    """ RandomLine class for representing and manipulating random lines in n-dimensional coordinates. """
    
    def __init__(self, dim=1, lower=0.0, upper=1.0):
        """ Create a new random line assuming a uniform distribution between the upper and lower bounds. 
        Args:
        dim (int): Dimension.
        lower (float): Lower bound.
        upper (float): Upper bound.
        """        
        self.points = [RandomPoint(dim, lower, upper) for i in range(0,2)] # inputs (list(RandomPoint))
    
    def target_function(self, randomPoint):
        """ Evaluate target function using equation of line in symmetric form.
        https://math.stackexchange.com/questions/274712/calculate-on-which-side-of-a-straight-line-is-a-given-point-located.
        https://en.wikipedia.org/wiki/Linear_equation.
        Args:
        randomPoint (RandomPoint): Random point.
        Returns: 
        int. +1 for the point being above the line. -1 for the point being below the line. 0 otherwise.     
        """
        x_minus_x1  = randomPoint.point[0] - self.points[0].point[0]
        y_minus_y1  = randomPoint.point[1] - self.points[0].point[1]
        y2_minus_y1 = self.points[1].point[1] - self.points[0].point[1]
        x2_minus_x1 = self.points[1].point[0] - self.points[0].point[0]
        
        return np.sign(x_minus_x1 * y2_minus_y1 - y_minus_y1 * x2_minus_x1)
    
    def weights(self):
        """ Evaluate weights of equation of line in symmetric form, i.e. w0 * x0 + w1 * x1 + w2 * x2 = 0
        https://math.stackexchange.com/questions/274712/calculate-on-which-side-of-a-straight-line-is-a-given-point-located.
        https://en.wikipedia.org/wiki/Linear_equation.
        Returns: 
        np.ndarray consisting of weights of the line [w0, w1, w2]    
        """
        y1_times_x2 = self.points[0].point[1] * self.points[1].point[0]
        x1_times_y2 = self.points[0].point[0] * self.points[1].point[1]
        y2_minus_y1 = self.points[1].point[1] - self.points[0].point[1]
        x2_minus_x1 = self.points[1].point[0] - self.points[0].point[0] 
        
        return np.array([y1_times_x2 - x1_times_y2, y2_minus_y1, -x2_minus_x1])

# %%
class DataSet:
    """ DataSet class for representing and manipulating random datasets. """
    def __init__(self, N=10, dim=1, lower=0.0, upper=1.0):
        """ Create a new data set assuming a uniform distribution between the 
            upper and lower bounds. 
        Args:
        N (int): Number of points.
        dim (int): Dimension of points.
        lower (float): Lower bound.
        upper (float): Upper bound.
        """
        self.inputs = [RandomPoint(dim, lower, upper) for i in range(0,N)] # inputs (list(RandomPoint))
        self.outputs = [RandomLine(2, -1.0, 1.0).target_function(input) for input in self.inputs] # outputs (list(int))
        #self.data = list(zip(self.inputs, self.outputs)) # inputs (list(Tuple(RandomPoint, int)))

# %%
class PLA:
    """ Perceptron Learning Algorithm (PLA) class. """
    
    def __init__(self, initialWeights, trainingSet):
        """ Create a new Perceptron Learning Algorithm (PLA). 
        Args:
        dim (int): Dimension.
        lower (float): Lower bound.
        upper (float): Upper bound.
        """
        self.initialWeights = initialWeights # initial weights
        self.xn = np.array([np.insert(input.point, 0, 1.0) for input in trainingSet.inputs], copy=True) # training set inputs
        self.trainingSet = trainingSet
        #self.yn = np.array(trainingSet.outputs, copy=True) # training set outputs
    
    def run(self, randomLine, maxIterations=100):    
        """Run of Perceptron Learning Algorithm (PLA).
        Returns:
        g
        """        
        # calculate outputs
        #yn = np.array([randomLine.target_function(xn) for xn in self.xn], copy=True) # outputs (list(int))
        yn = np.array([randomLine.target_function(input) for input in self.trainingSet.inputs], copy=True) # outputs (list(int))
        
        # calculate target function (weights)
        targetWeights = randomLine.weights()
        #print('Target weights ', targetWeights)
        
        # misclassified points
        #misPointIdxs = self.misclassifiedPoints(self.initialWeights, yn)
          
        # PLA iterations
        numIterations = 0
        weights = np.copy(self.initialWeights) # initialize weights
        converged = False
        for i in range(0, maxIterations):
            numIterations += 1
            #print('Iteration # ', numIterations)
            
            # misclassified points
            misPointIdxs = self.misclassifiedPoints(weights, yn)
        
            # break out of loop if converged
            if len(misPointIdxs) == 0:
                converged = True
                print('PLA algorithm converged after ', numIterations, ' iterations')
                break
            
            # pick misclassified point at random
            misPointIdx = rd.choice(misPointIdxs)
            #print('Chosen misclassified point index ', misPointIdx)
            
            # update weights
            weights = np.add(weights, np.multiply(yn[misPointIdx], self.xn[misPointIdx]))
            #print('Weights ', weights)
            
        if not converged:
            raise Exception('Perceptron algorithm failed to converge after maximum number of iterations.')
        
        # estimate disagreement probability between f and g
        disagreementProb = self.disagreementProbability(1000, weights, targetWeights)
        
        return weights, numIterations, disagreementProb
    
    # private methods
    def misclassifiedPoints(self, weights, yn):
        misPointIdxs = []      
        for i in range(0, len(self.xn)):
            if np.sign(np.dot(weights, self.xn[i])) != yn[i]:
                misPointIdxs.append(i)
        #print('Misclassified point indexes', misPointIdxs)
        return misPointIdxs
    
    def disagreementProbability(self, npoints, weights, targetWeights):
        # generate random points
        estPoints = [RandomPoint(2, -1.0, 1.0) for i in range(0,npoints)]
        points = np.array([np.insert(estPoint.point, 0, 1.0) for estPoint in estPoints])
        
        # calculate probability
        disagreementProb = 0
        for point in points:
            g = np.sign(weights[0] * point[0] + weights[1] * point[1] + weights[2] * point[2])
            f = np.sign(targetWeights[0] * point[0] + targetWeights[1] * point[1] + targetWeights[2] * point[2])
            if g != f:
                disagreementProb += 1
                
        return float(disagreementProb / npoints)

# %%
def runPerceptron(initialWeights, trainingSet, numRuns=1, maxIterations=100):
    '''Run perceptron algorithm.
    Args: 
    numRuns (int): number of runs
    
    Returns:
    meanIterations (float): mean number of iterations for convergence
    '''
    meanIterations = 0
    meanDisagreementProb = 0.0
    for i in range(0, numRuns):
        pla = PLA(initialWeights, trainingSet)
        weights, numIterations, disagreementProb = pla.run(RandomLine(2, -1.0, 1.0), maxIterations)
        #print('Final weights ', weights)
        meanIterations += numIterations
        meanDisagreementProb += disagreementProb
    
    meanIterations = meanIterations / numRuns
    meanDisagreementProb = meanDisagreementProb / numRuns
    
    return meanIterations, meanDisagreementProb

# %%
trainingSet = DataSet(N=10, dim=2, lower=-1.0, upper=1.0)
meanIterations, meanDisagreementProb = runPerceptron(np.array([0.0, 0.0, 0.0]), trainingSet, numRuns=1000, maxIterations=1000)
print('Average number of iterations = ', meanIterations)
print('Average disagreement probability between f and g = ', meanDisagreementProb)
# Out:
# PLA algorithm converged after  34  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  20  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  32  iterations
# PLA algorithm converged after  20  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  32  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  20  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  13  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  18  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  23  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  9  iterations
# PLA algorithm converged after  16  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  15  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  22  iterations
# PLA algorithm converged after  22  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  22  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  18  iterations
# PLA algorithm converged after  11  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  9  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  16  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  25  iterations
# PLA algorithm converged after  15  iterations
# PLA algorithm converged after  42  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  18  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  45  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  16  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  17  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  9  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  46  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  11  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  22  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  9  iterations
# PLA algorithm converged after  40  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  25  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  86  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  23  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  20  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  16  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  11  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  32  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  27  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  81  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  44  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  15  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  42  iterations
# PLA algorithm converged after  22  iterations
# PLA algorithm converged after  78  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  15  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  16  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  9  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  42  iterations
# PLA algorithm converged after  20  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  13  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  82  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  37  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  18  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  32  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  59  iterations
# PLA algorithm converged after  45  iterations
# PLA algorithm converged after  49  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  25  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  44  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  15  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  18  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  11  iterations
# PLA algorithm converged after  16  iterations
# PLA algorithm converged after  9  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  22  iterations
# PLA algorithm converged after  17  iterations
# PLA algorithm converged after  13  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  13  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  20  iterations
# PLA algorithm converged after  18  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  51  iterations
# PLA algorithm converged after  28  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  16  iterations
# PLA algorithm converged after  16  iterations
# PLA algorithm converged after  11  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  42  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  16  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  21  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  11  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  50  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  18  iterations
# PLA algorithm converged after  16  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  9  iterations
# PLA algorithm converged after  78  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  49  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  11  iterations
# PLA algorithm converged after  24  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  80  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  38  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  11  iterations
# PLA algorithm converged after  40  iterations
# PLA algorithm converged after  18  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  25  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  26  iterations
# PLA algorithm converged after  13  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  16  iterations
# PLA algorithm converged after  9  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  18  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  9  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  28  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  17  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  26  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  49  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  25  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  34  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  33  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  22  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  9  iterations
# PLA algorithm converged after  16  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  9  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  20  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  72  iterations
# PLA algorithm converged after  24  iterations
# PLA algorithm converged after  20  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  21  iterations
# PLA algorithm converged after  11  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  9  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  18  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  37  iterations
# PLA algorithm converged after  11  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  42  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  18  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  28  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  34  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  22  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  42  iterations
# PLA algorithm converged after  16  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  13  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  22  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  25  iterations
# PLA algorithm converged after  34  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  22  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  18  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  48  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  22  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  28  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  20  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  18  iterations
# PLA algorithm converged after  88  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  24  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  9  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  45  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  24  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  22  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  20  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  57  iterations
# PLA algorithm converged after  13  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  33  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  19  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  19  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  26  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  18  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  15  iterations
# PLA algorithm converged after  50  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  18  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  38  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  30  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  19  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  88  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  18  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  39  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  18  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  9  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  82  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  9  iterations
# PLA algorithm converged after  17  iterations
# PLA algorithm converged after  26  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  26  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  35  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  11  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  29  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  15  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  18  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  20  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  24  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  23  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  38  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  16  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  13  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  47  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  11  iterations
# PLA algorithm converged after  21  iterations
# PLA algorithm converged after  11  iterations
# PLA algorithm converged after  52  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  27  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  94  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  28  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  11  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  16  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  29  iterations
# PLA algorithm converged after  34  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  31  iterations
# PLA algorithm converged after  18  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  24  iterations
# PLA algorithm converged after  24  iterations
# PLA algorithm converged after  18  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  18  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  33  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  16  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  25  iterations
# PLA algorithm converged after  71  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  13  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  20  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  44  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  26  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  20  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  16  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  19  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  13  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  28  iterations
# PLA algorithm converged after  24  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  17  iterations
# PLA algorithm converged after  26  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  22  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  22  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  44  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  16  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  11  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  22  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  11  iterations
# PLA algorithm converged after  49  iterations
# PLA algorithm converged after  22  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  18  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  16  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  11  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  22  iterations
# PLA algorithm converged after  27  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  36  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  17  iterations
# PLA algorithm converged after  42  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  11  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  13  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  39  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  32  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  41  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  13  iterations
# PLA algorithm converged after  13  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  48  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  6  iterations
# Average number of iterations =  11.252
# Average disagreement probability between f and g =  0.089543

# %%
trainingSet = DataSet(N=100, dim=2, lower=-1.0, upper=1.0)
meanIterations, meanDisagreementProb = runPerceptron(np.array([0.0, 0.0, 0.0]), trainingSet, numRuns=1000, maxIterations=100000)
print('Average number of iterations = ', meanIterations)
print('Average disagreement probability between f and g = ', meanDisagreementProb)
# Out:
# PLA algorithm converged after  68  iterations
# PLA algorithm converged after  25  iterations
# PLA algorithm converged after  212  iterations
# PLA algorithm converged after  16  iterations
# PLA algorithm converged after  30  iterations
# PLA algorithm converged after  33  iterations
# PLA algorithm converged after  57  iterations
# PLA algorithm converged after  30  iterations
# PLA algorithm converged after  104  iterations
# PLA algorithm converged after  34  iterations
# PLA algorithm converged after  232  iterations
# PLA algorithm converged after  34  iterations
# PLA algorithm converged after  13  iterations
# PLA algorithm converged after  32  iterations
# PLA algorithm converged after  178  iterations
# PLA algorithm converged after  59  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  145  iterations
# PLA algorithm converged after  32  iterations
# PLA algorithm converged after  1196  iterations
# PLA algorithm converged after  40  iterations
# PLA algorithm converged after  242  iterations
# PLA algorithm converged after  138  iterations
# PLA algorithm converged after  58  iterations
# PLA algorithm converged after  43  iterations
# PLA algorithm converged after  32  iterations
# PLA algorithm converged after  66  iterations
# PLA algorithm converged after  32  iterations
# PLA algorithm converged after  200  iterations
# PLA algorithm converged after  1280  iterations
# PLA algorithm converged after  49  iterations
# PLA algorithm converged after  20  iterations
# PLA algorithm converged after  466  iterations
# PLA algorithm converged after  81  iterations
# PLA algorithm converged after  48  iterations
# PLA algorithm converged after  69  iterations
# PLA algorithm converged after  26  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  65  iterations
# PLA algorithm converged after  26  iterations
# PLA algorithm converged after  25  iterations
# PLA algorithm converged after  171  iterations
# PLA algorithm converged after  64  iterations
# PLA algorithm converged after  45  iterations
# PLA algorithm converged after  133  iterations
# PLA algorithm converged after  32  iterations
# PLA algorithm converged after  78  iterations
# PLA algorithm converged after  25  iterations
# PLA algorithm converged after  36  iterations
# PLA algorithm converged after  102  iterations
# PLA algorithm converged after  112  iterations
# PLA algorithm converged after  72  iterations
# PLA algorithm converged after  224  iterations
# PLA algorithm converged after  142  iterations
# PLA algorithm converged after  115  iterations
# PLA algorithm converged after  123  iterations
# PLA algorithm converged after  34  iterations
# PLA algorithm converged after  94  iterations
# PLA algorithm converged after  84  iterations
# PLA algorithm converged after  65  iterations
# PLA algorithm converged after  59  iterations
# PLA algorithm converged after  278  iterations
# PLA algorithm converged after  31  iterations
# PLA algorithm converged after  43  iterations
# PLA algorithm converged after  266  iterations
# PLA algorithm converged after  100  iterations
# PLA algorithm converged after  277  iterations
# PLA algorithm converged after  106  iterations
# PLA algorithm converged after  112  iterations
# PLA algorithm converged after  28  iterations
# PLA algorithm converged after  459  iterations
# PLA algorithm converged after  116  iterations
# PLA algorithm converged after  13  iterations
# PLA algorithm converged after  79  iterations
# PLA algorithm converged after  71  iterations
# PLA algorithm converged after  72  iterations
# PLA algorithm converged after  84  iterations
# PLA algorithm converged after  132  iterations
# PLA algorithm converged after  110  iterations
# PLA algorithm converged after  136  iterations
# PLA algorithm converged after  21  iterations
# PLA algorithm converged after  63  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  40  iterations
# PLA algorithm converged after  478  iterations
# PLA algorithm converged after  73  iterations
# PLA algorithm converged after  24  iterations
# PLA algorithm converged after  61  iterations
# PLA algorithm converged after  37  iterations
# PLA algorithm converged after  96  iterations
# PLA algorithm converged after  192  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  3904  iterations
# PLA algorithm converged after  43  iterations
# PLA algorithm converged after  114  iterations
# PLA algorithm converged after  85  iterations
# PLA algorithm converged after  66  iterations
# PLA algorithm converged after  142  iterations
# PLA algorithm converged after  35  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  77  iterations
# PLA algorithm converged after  120  iterations
# PLA algorithm converged after  250  iterations
# PLA algorithm converged after  88  iterations
# PLA algorithm converged after  100  iterations
# PLA algorithm converged after  105  iterations
# PLA algorithm converged after  462  iterations
# PLA algorithm converged after  27  iterations
# PLA algorithm converged after  110  iterations
# PLA algorithm converged after  44  iterations
# PLA algorithm converged after  1042  iterations
# PLA algorithm converged after  30  iterations
# PLA algorithm converged after  74  iterations
# PLA algorithm converged after  59  iterations
# PLA algorithm converged after  47  iterations
# PLA algorithm converged after  64  iterations
# PLA algorithm converged after  20  iterations
# PLA algorithm converged after  66  iterations
# PLA algorithm converged after  58  iterations
# PLA algorithm converged after  102  iterations
# PLA algorithm converged after  37  iterations
# PLA algorithm converged after  43  iterations
# PLA algorithm converged after  71  iterations
# PLA algorithm converged after  28  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  56  iterations
# PLA algorithm converged after  55  iterations
# PLA algorithm converged after  111  iterations
# PLA algorithm converged after  87  iterations
# PLA algorithm converged after  154  iterations
# PLA algorithm converged after  88  iterations
# PLA algorithm converged after  51  iterations
# PLA algorithm converged after  131  iterations
# PLA algorithm converged after  20  iterations
# PLA algorithm converged after  90  iterations
# PLA algorithm converged after  23  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  11  iterations
# PLA algorithm converged after  78  iterations
# PLA algorithm converged after  91  iterations
# PLA algorithm converged after  106  iterations
# PLA algorithm converged after  104  iterations
# PLA algorithm converged after  204  iterations
# PLA algorithm converged after  53  iterations
# PLA algorithm converged after  192  iterations
# PLA algorithm converged after  30  iterations
# PLA algorithm converged after  59  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  185  iterations
# PLA algorithm converged after  214  iterations
# PLA algorithm converged after  19  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  61  iterations
# PLA algorithm converged after  47  iterations
# PLA algorithm converged after  48  iterations
# PLA algorithm converged after  27  iterations
# PLA algorithm converged after  72  iterations
# PLA algorithm converged after  257  iterations
# PLA algorithm converged after  260  iterations
# PLA algorithm converged after  87  iterations
# PLA algorithm converged after  193  iterations
# PLA algorithm converged after  190  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  31  iterations
# PLA algorithm converged after  55  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  18  iterations
# PLA algorithm converged after  23  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  408  iterations
# PLA algorithm converged after  42  iterations
# PLA algorithm converged after  27  iterations
# PLA algorithm converged after  26  iterations
# PLA algorithm converged after  65  iterations
# PLA algorithm converged after  150  iterations
# PLA algorithm converged after  79  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  283  iterations
# PLA algorithm converged after  390  iterations
# PLA algorithm converged after  36  iterations
# PLA algorithm converged after  132  iterations
# PLA algorithm converged after  56  iterations
# PLA algorithm converged after  74  iterations
# PLA algorithm converged after  28  iterations
# PLA algorithm converged after  32  iterations
# PLA algorithm converged after  94  iterations
# PLA algorithm converged after  11  iterations
# PLA algorithm converged after  67  iterations
# PLA algorithm converged after  38  iterations
# PLA algorithm converged after  161  iterations
# PLA algorithm converged after  32  iterations
# PLA algorithm converged after  29  iterations
# PLA algorithm converged after  18  iterations
# PLA algorithm converged after  74  iterations
# PLA algorithm converged after  110  iterations
# PLA algorithm converged after  101  iterations
# PLA algorithm converged after  662  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  1566  iterations
# PLA algorithm converged after  149  iterations
# PLA algorithm converged after  51  iterations
# PLA algorithm converged after  142  iterations
# PLA algorithm converged after  44  iterations
# PLA algorithm converged after  153  iterations
# PLA algorithm converged after  51  iterations
# PLA algorithm converged after  84  iterations
# PLA algorithm converged after  44  iterations
# PLA algorithm converged after  24  iterations
# PLA algorithm converged after  52  iterations
# PLA algorithm converged after  18  iterations
# PLA algorithm converged after  51  iterations
# PLA algorithm converged after  92  iterations
# PLA algorithm converged after  30  iterations
# PLA algorithm converged after  42  iterations
# PLA algorithm converged after  63  iterations
# PLA algorithm converged after  94  iterations
# PLA algorithm converged after  43  iterations
# PLA algorithm converged after  46  iterations
# PLA algorithm converged after  387  iterations
# PLA algorithm converged after  40  iterations
# PLA algorithm converged after  53  iterations
# PLA algorithm converged after  126  iterations
# PLA algorithm converged after  61  iterations
# PLA algorithm converged after  82  iterations
# PLA algorithm converged after  150  iterations
# PLA algorithm converged after  26  iterations
# PLA algorithm converged after  69  iterations
# PLA algorithm converged after  69  iterations
# PLA algorithm converged after  63  iterations
# PLA algorithm converged after  13  iterations
# PLA algorithm converged after  1234  iterations
# PLA algorithm converged after  48  iterations
# PLA algorithm converged after  53  iterations
# PLA algorithm converged after  21  iterations
# PLA algorithm converged after  52  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  59  iterations
# PLA algorithm converged after  128  iterations
# PLA algorithm converged after  86  iterations
# PLA algorithm converged after  20  iterations
# PLA algorithm converged after  24  iterations
# PLA algorithm converged after  285  iterations
# PLA algorithm converged after  131  iterations
# PLA algorithm converged after  41  iterations
# PLA algorithm converged after  44  iterations
# PLA algorithm converged after  748  iterations
# PLA algorithm converged after  55  iterations
# PLA algorithm converged after  143  iterations
# PLA algorithm converged after  16  iterations
# PLA algorithm converged after  334  iterations
# PLA algorithm converged after  74  iterations
# PLA algorithm converged after  29  iterations
# PLA algorithm converged after  25  iterations
# PLA algorithm converged after  80  iterations
# PLA algorithm converged after  26  iterations
# PLA algorithm converged after  376  iterations
# PLA algorithm converged after  98  iterations
# PLA algorithm converged after  94  iterations
# PLA algorithm converged after  47  iterations
# PLA algorithm converged after  32  iterations
# PLA algorithm converged after  316  iterations
# PLA algorithm converged after  35  iterations
# PLA algorithm converged after  44  iterations
# PLA algorithm converged after  43  iterations
# PLA algorithm converged after  13  iterations
# PLA algorithm converged after  125  iterations
# PLA algorithm converged after  46  iterations
# PLA algorithm converged after  34  iterations
# PLA algorithm converged after  26  iterations
# PLA algorithm converged after  38  iterations
# PLA algorithm converged after  36  iterations
# PLA algorithm converged after  161  iterations
# PLA algorithm converged after  79  iterations
# PLA algorithm converged after  41  iterations
# PLA algorithm converged after  267  iterations
# PLA algorithm converged after  244  iterations
# PLA algorithm converged after  105  iterations
# PLA algorithm converged after  29  iterations
# PLA algorithm converged after  54  iterations
# PLA algorithm converged after  47  iterations
# PLA algorithm converged after  136  iterations
# PLA algorithm converged after  72  iterations
# PLA algorithm converged after  74  iterations
# PLA algorithm converged after  37  iterations
# PLA algorithm converged after  40  iterations
# PLA algorithm converged after  1914  iterations
# PLA algorithm converged after  48  iterations
# PLA algorithm converged after  116  iterations
# PLA algorithm converged after  252  iterations
# PLA algorithm converged after  22  iterations
# PLA algorithm converged after  72  iterations
# PLA algorithm converged after  195  iterations
# PLA algorithm converged after  52  iterations
# PLA algorithm converged after  36  iterations
# PLA algorithm converged after  166  iterations
# PLA algorithm converged after  215  iterations
# PLA algorithm converged after  113  iterations
# PLA algorithm converged after  53  iterations
# PLA algorithm converged after  105  iterations
# PLA algorithm converged after  233  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  26  iterations
# PLA algorithm converged after  63  iterations
# PLA algorithm converged after  193  iterations
# PLA algorithm converged after  104  iterations
# PLA algorithm converged after  37  iterations
# PLA algorithm converged after  424  iterations
# PLA algorithm converged after  35  iterations
# PLA algorithm converged after  60  iterations
# PLA algorithm converged after  27  iterations
# PLA algorithm converged after  104  iterations
# PLA algorithm converged after  406  iterations
# PLA algorithm converged after  65  iterations
# PLA algorithm converged after  27  iterations
# PLA algorithm converged after  43  iterations
# PLA algorithm converged after  174  iterations
# PLA algorithm converged after  201  iterations
# PLA algorithm converged after  26  iterations
# PLA algorithm converged after  38  iterations
# PLA algorithm converged after  40  iterations
# PLA algorithm converged after  33  iterations
# PLA algorithm converged after  19  iterations
# PLA algorithm converged after  42  iterations
# PLA algorithm converged after  22  iterations
# PLA algorithm converged after  48  iterations
# PLA algorithm converged after  76  iterations
# PLA algorithm converged after  16  iterations
# PLA algorithm converged after  33  iterations
# PLA algorithm converged after  28  iterations
# PLA algorithm converged after  44  iterations
# PLA algorithm converged after  46  iterations
# PLA algorithm converged after  86  iterations
# PLA algorithm converged after  64  iterations
# PLA algorithm converged after  43  iterations
# PLA algorithm converged after  86  iterations
# PLA algorithm converged after  63  iterations
# PLA algorithm converged after  36  iterations
# PLA algorithm converged after  50  iterations
# PLA algorithm converged after  104  iterations
# PLA algorithm converged after  84  iterations
# PLA algorithm converged after  52  iterations
# PLA algorithm converged after  31  iterations
# PLA algorithm converged after  1354  iterations
# PLA algorithm converged after  206  iterations
# PLA algorithm converged after  80  iterations
# PLA algorithm converged after  114  iterations
# PLA algorithm converged after  124  iterations
# PLA algorithm converged after  46  iterations
# PLA algorithm converged after  25  iterations
# PLA algorithm converged after  56  iterations
# PLA algorithm converged after  17  iterations
# PLA algorithm converged after  65  iterations
# PLA algorithm converged after  31  iterations
# PLA algorithm converged after  79  iterations
# PLA algorithm converged after  45  iterations
# PLA algorithm converged after  20  iterations
# PLA algorithm converged after  68  iterations
# PLA algorithm converged after  61  iterations
# PLA algorithm converged after  78  iterations
# PLA algorithm converged after  1224  iterations
# PLA algorithm converged after  73  iterations
# PLA algorithm converged after  21  iterations
# PLA algorithm converged after  59  iterations
# PLA algorithm converged after  181  iterations
# PLA algorithm converged after  64  iterations
# PLA algorithm converged after  82  iterations
# PLA algorithm converged after  50  iterations
# PLA algorithm converged after  50  iterations
# PLA algorithm converged after  54  iterations
# PLA algorithm converged after  152  iterations
# PLA algorithm converged after  868  iterations
# PLA algorithm converged after  94  iterations
# PLA algorithm converged after  34  iterations
# PLA algorithm converged after  27  iterations
# PLA algorithm converged after  57  iterations
# PLA algorithm converged after  568  iterations
# PLA algorithm converged after  22  iterations
# PLA algorithm converged after  56  iterations
# PLA algorithm converged after  47  iterations
# PLA algorithm converged after  165  iterations
# PLA algorithm converged after  28  iterations
# PLA algorithm converged after  240  iterations
# PLA algorithm converged after  129  iterations
# PLA algorithm converged after  175  iterations
# PLA algorithm converged after  144  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  143  iterations
# PLA algorithm converged after  146  iterations
# PLA algorithm converged after  40  iterations
# PLA algorithm converged after  70  iterations
# PLA algorithm converged after  101  iterations
# PLA algorithm converged after  49  iterations
# PLA algorithm converged after  85  iterations
# PLA algorithm converged after  27  iterations
# PLA algorithm converged after  31  iterations
# PLA algorithm converged after  80  iterations
# PLA algorithm converged after  1392  iterations
# PLA algorithm converged after  29  iterations
# PLA algorithm converged after  646  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  742  iterations
# PLA algorithm converged after  69  iterations
# PLA algorithm converged after  319  iterations
# PLA algorithm converged after  64  iterations
# PLA algorithm converged after  16  iterations
# PLA algorithm converged after  80  iterations
# PLA algorithm converged after  162  iterations
# PLA algorithm converged after  70  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  30  iterations
# PLA algorithm converged after  123  iterations
# PLA algorithm converged after  198  iterations
# PLA algorithm converged after  80  iterations
# PLA algorithm converged after  91  iterations
# PLA algorithm converged after  20  iterations
# PLA algorithm converged after  46  iterations
# PLA algorithm converged after  240  iterations
# PLA algorithm converged after  66  iterations
# PLA algorithm converged after  86  iterations
# PLA algorithm converged after  93  iterations
# PLA algorithm converged after  22  iterations
# PLA algorithm converged after  86  iterations
# PLA algorithm converged after  206  iterations
# PLA algorithm converged after  125  iterations
# PLA algorithm converged after  135  iterations
# PLA algorithm converged after  18  iterations
# PLA algorithm converged after  22  iterations
# PLA algorithm converged after  131  iterations
# PLA algorithm converged after  247  iterations
# PLA algorithm converged after  268  iterations
# PLA algorithm converged after  48  iterations
# PLA algorithm converged after  50  iterations
# PLA algorithm converged after  171  iterations
# PLA algorithm converged after  122  iterations
# PLA algorithm converged after  30  iterations
# PLA algorithm converged after  42  iterations
# PLA algorithm converged after  24  iterations
# PLA algorithm converged after  75  iterations
# PLA algorithm converged after  78  iterations
# PLA algorithm converged after  17  iterations
# PLA algorithm converged after  92  iterations
# PLA algorithm converged after  59  iterations
# PLA algorithm converged after  758  iterations
# PLA algorithm converged after  105  iterations
# PLA algorithm converged after  2  iterations
# PLA algorithm converged after  69  iterations
# PLA algorithm converged after  94  iterations
# PLA algorithm converged after  32  iterations
# PLA algorithm converged after  29  iterations
# PLA algorithm converged after  22  iterations
# PLA algorithm converged after  99  iterations
# PLA algorithm converged after  21  iterations
# PLA algorithm converged after  27  iterations
# PLA algorithm converged after  29  iterations
# PLA algorithm converged after  22  iterations
# PLA algorithm converged after  21  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  112  iterations
# PLA algorithm converged after  22  iterations
# PLA algorithm converged after  34  iterations
# PLA algorithm converged after  47  iterations
# PLA algorithm converged after  29  iterations
# PLA algorithm converged after  102  iterations
# PLA algorithm converged after  75  iterations
# PLA algorithm converged after  19  iterations
# PLA algorithm converged after  121  iterations
# PLA algorithm converged after  32  iterations
# PLA algorithm converged after  24  iterations
# PLA algorithm converged after  104  iterations
# PLA algorithm converged after  17  iterations
# PLA algorithm converged after  5484  iterations
# PLA algorithm converged after  25  iterations
# PLA algorithm converged after  73  iterations
# PLA algorithm converged after  808  iterations
# PLA algorithm converged after  9  iterations
# PLA algorithm converged after  69  iterations
# PLA algorithm converged after  116  iterations
# PLA algorithm converged after  313  iterations
# PLA algorithm converged after  79  iterations
# PLA algorithm converged after  270  iterations
# PLA algorithm converged after  66  iterations
# PLA algorithm converged after  102  iterations
# PLA algorithm converged after  88  iterations
# PLA algorithm converged after  153  iterations
# PLA algorithm converged after  95  iterations
# PLA algorithm converged after  117  iterations
# PLA algorithm converged after  44  iterations
# PLA algorithm converged after  5  iterations
# PLA algorithm converged after  65  iterations
# PLA algorithm converged after  47  iterations
# PLA algorithm converged after  18  iterations
# PLA algorithm converged after  20  iterations
# PLA algorithm converged after  586  iterations
# PLA algorithm converged after  64  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  58  iterations
# PLA algorithm converged after  140  iterations
# PLA algorithm converged after  68  iterations
# PLA algorithm converged after  70  iterations
# PLA algorithm converged after  49  iterations
# PLA algorithm converged after  44  iterations
# PLA algorithm converged after  64  iterations
# PLA algorithm converged after  177  iterations
# PLA algorithm converged after  22  iterations
# PLA algorithm converged after  20  iterations
# PLA algorithm converged after  47  iterations
# PLA algorithm converged after  48  iterations
# PLA algorithm converged after  63  iterations
# PLA algorithm converged after  135  iterations
# PLA algorithm converged after  69  iterations
# PLA algorithm converged after  50  iterations
# PLA algorithm converged after  59  iterations
# PLA algorithm converged after  45  iterations
# PLA algorithm converged after  82  iterations
# PLA algorithm converged after  225  iterations
# PLA algorithm converged after  20  iterations
# PLA algorithm converged after  199  iterations
# PLA algorithm converged after  23  iterations
# PLA algorithm converged after  70  iterations
# PLA algorithm converged after  39  iterations
# PLA algorithm converged after  41  iterations
# PLA algorithm converged after  80  iterations
# PLA algorithm converged after  58  iterations
# PLA algorithm converged after  55  iterations
# PLA algorithm converged after  680  iterations
# PLA algorithm converged after  398  iterations
# PLA algorithm converged after  52  iterations
# PLA algorithm converged after  90  iterations
# PLA algorithm converged after  71  iterations
# PLA algorithm converged after  101  iterations
# PLA algorithm converged after  102  iterations
# PLA algorithm converged after  268  iterations
# PLA algorithm converged after  242  iterations
# PLA algorithm converged after  136  iterations
# PLA algorithm converged after  159  iterations
# PLA algorithm converged after  47  iterations
# PLA algorithm converged after  32  iterations
# PLA algorithm converged after  74  iterations
# PLA algorithm converged after  314  iterations
# PLA algorithm converged after  458  iterations
# PLA algorithm converged after  46  iterations
# PLA algorithm converged after  25  iterations
# PLA algorithm converged after  37  iterations
# PLA algorithm converged after  55  iterations
# PLA algorithm converged after  61  iterations
# PLA algorithm converged after  16  iterations
# PLA algorithm converged after  284  iterations
# PLA algorithm converged after  71  iterations
# PLA algorithm converged after  116  iterations
# PLA algorithm converged after  150  iterations
# PLA algorithm converged after  46  iterations
# PLA algorithm converged after  50  iterations
# PLA algorithm converged after  46  iterations
# PLA algorithm converged after  54  iterations
# PLA algorithm converged after  203  iterations
# PLA algorithm converged after  92  iterations
# PLA algorithm converged after  53  iterations
# PLA algorithm converged after  142  iterations
# PLA algorithm converged after  70  iterations
# PLA algorithm converged after  130  iterations
# PLA algorithm converged after  84  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  132  iterations
# PLA algorithm converged after  47  iterations
# PLA algorithm converged after  46  iterations
# PLA algorithm converged after  68  iterations
# PLA algorithm converged after  25  iterations
# PLA algorithm converged after  35  iterations
# PLA algorithm converged after  83  iterations
# PLA algorithm converged after  35  iterations
# PLA algorithm converged after  21  iterations
# PLA algorithm converged after  96  iterations
# PLA algorithm converged after  47  iterations
# PLA algorithm converged after  16  iterations
# PLA algorithm converged after  61  iterations
# PLA algorithm converged after  118  iterations
# PLA algorithm converged after  58  iterations
# PLA algorithm converged after  158  iterations
# PLA algorithm converged after  104  iterations
# PLA algorithm converged after  103  iterations
# PLA algorithm converged after  152  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  22  iterations
# PLA algorithm converged after  32  iterations
# PLA algorithm converged after  25  iterations
# PLA algorithm converged after  15  iterations
# PLA algorithm converged after  27  iterations
# PLA algorithm converged after  101  iterations
# PLA algorithm converged after  59  iterations
# PLA algorithm converged after  9  iterations
# PLA algorithm converged after  37  iterations
# PLA algorithm converged after  41  iterations
# PLA algorithm converged after  42  iterations
# PLA algorithm converged after  42  iterations
# PLA algorithm converged after  28  iterations
# PLA algorithm converged after  353  iterations
# PLA algorithm converged after  124  iterations
# PLA algorithm converged after  37  iterations
# PLA algorithm converged after  42  iterations
# PLA algorithm converged after  40  iterations
# PLA algorithm converged after  129  iterations
# PLA algorithm converged after  168  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  79  iterations
# PLA algorithm converged after  171  iterations
# PLA algorithm converged after  104  iterations
# PLA algorithm converged after  123  iterations
# PLA algorithm converged after  66  iterations
# PLA algorithm converged after  346  iterations
# PLA algorithm converged after  42  iterations
# PLA algorithm converged after  25  iterations
# PLA algorithm converged after  72  iterations
# PLA algorithm converged after  155  iterations
# PLA algorithm converged after  50  iterations
# PLA algorithm converged after  19  iterations
# PLA algorithm converged after  16  iterations
# PLA algorithm converged after  183  iterations
# PLA algorithm converged after  195  iterations
# PLA algorithm converged after  41  iterations
# PLA algorithm converged after  80  iterations
# PLA algorithm converged after  654  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  31  iterations
# PLA algorithm converged after  81  iterations
# PLA algorithm converged after  66  iterations
# PLA algorithm converged after  226  iterations
# PLA algorithm converged after  81  iterations
# PLA algorithm converged after  66  iterations
# PLA algorithm converged after  23  iterations
# PLA algorithm converged after  65  iterations
# PLA algorithm converged after  112  iterations
# PLA algorithm converged after  65  iterations
# PLA algorithm converged after  59  iterations
# PLA algorithm converged after  46  iterations
# PLA algorithm converged after  33  iterations
# PLA algorithm converged after  53  iterations
# PLA algorithm converged after  47  iterations
# PLA algorithm converged after  146  iterations
# PLA algorithm converged after  117  iterations
# PLA algorithm converged after  30  iterations
# PLA algorithm converged after  59  iterations
# PLA algorithm converged after  336  iterations
# PLA algorithm converged after  78  iterations
# PLA algorithm converged after  42  iterations
# PLA algorithm converged after  63  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  1317  iterations
# PLA algorithm converged after  29  iterations
# PLA algorithm converged after  1200  iterations
# PLA algorithm converged after  16  iterations
# PLA algorithm converged after  38  iterations
# PLA algorithm converged after  44  iterations
# PLA algorithm converged after  23  iterations
# PLA algorithm converged after  22  iterations
# PLA algorithm converged after  17  iterations
# PLA algorithm converged after  11  iterations
# PLA algorithm converged after  87  iterations
# PLA algorithm converged after  58  iterations
# PLA algorithm converged after  54  iterations
# PLA algorithm converged after  56  iterations
# PLA algorithm converged after  32  iterations
# PLA algorithm converged after  1744  iterations
# PLA algorithm converged after  38  iterations
# PLA algorithm converged after  26  iterations
# PLA algorithm converged after  58  iterations
# PLA algorithm converged after  139  iterations
# PLA algorithm converged after  97  iterations
# PLA algorithm converged after  124  iterations
# PLA algorithm converged after  265  iterations
# PLA algorithm converged after  32  iterations
# PLA algorithm converged after  162  iterations
# PLA algorithm converged after  102  iterations
# PLA algorithm converged after  700  iterations
# PLA algorithm converged after  45  iterations
# PLA algorithm converged after  69  iterations
# PLA algorithm converged after  103  iterations
# PLA algorithm converged after  33  iterations
# PLA algorithm converged after  117  iterations
# PLA algorithm converged after  62  iterations
# PLA algorithm converged after  57  iterations
# PLA algorithm converged after  365  iterations
# PLA algorithm converged after  29  iterations
# PLA algorithm converged after  62  iterations
# PLA algorithm converged after  22  iterations
# PLA algorithm converged after  115  iterations
# PLA algorithm converged after  30  iterations
# PLA algorithm converged after  29  iterations
# PLA algorithm converged after  22  iterations
# PLA algorithm converged after  152  iterations
# PLA algorithm converged after  335  iterations
# PLA algorithm converged after  67  iterations
# PLA algorithm converged after  406  iterations
# PLA algorithm converged after  89  iterations
# PLA algorithm converged after  85  iterations
# PLA algorithm converged after  24  iterations
# PLA algorithm converged after  99  iterations
# PLA algorithm converged after  61  iterations
# PLA algorithm converged after  25  iterations
# PLA algorithm converged after  284  iterations
# PLA algorithm converged after  60  iterations
# PLA algorithm converged after  26  iterations
# PLA algorithm converged after  199  iterations
# PLA algorithm converged after  44  iterations
# PLA algorithm converged after  58  iterations
# PLA algorithm converged after  39  iterations
# PLA algorithm converged after  85  iterations
# PLA algorithm converged after  56  iterations
# PLA algorithm converged after  41  iterations
# PLA algorithm converged after  71  iterations
# PLA algorithm converged after  25  iterations
# PLA algorithm converged after  16  iterations
# PLA algorithm converged after  53  iterations
# PLA algorithm converged after  112  iterations
# PLA algorithm converged after  47  iterations
# PLA algorithm converged after  248  iterations
# PLA algorithm converged after  13  iterations
# PLA algorithm converged after  36  iterations
# PLA algorithm converged after  28  iterations
# PLA algorithm converged after  41  iterations
# PLA algorithm converged after  117  iterations
# PLA algorithm converged after  35  iterations
# PLA algorithm converged after  53  iterations
# PLA algorithm converged after  230  iterations
# PLA algorithm converged after  76  iterations
# PLA algorithm converged after  90  iterations
# PLA algorithm converged after  64  iterations
# PLA algorithm converged after  35  iterations
# PLA algorithm converged after  206  iterations
# PLA algorithm converged after  85  iterations
# PLA algorithm converged after  53  iterations
# PLA algorithm converged after  15  iterations
# PLA algorithm converged after  360  iterations
# PLA algorithm converged after  167  iterations
# PLA algorithm converged after  54  iterations
# PLA algorithm converged after  49  iterations
# PLA algorithm converged after  782  iterations
# PLA algorithm converged after  48  iterations
# PLA algorithm converged after  191  iterations
# PLA algorithm converged after  116  iterations
# PLA algorithm converged after  97  iterations
# PLA algorithm converged after  109  iterations
# PLA algorithm converged after  43  iterations
# PLA algorithm converged after  42  iterations
# PLA algorithm converged after  29  iterations
# PLA algorithm converged after  147  iterations
# PLA algorithm converged after  1206  iterations
# PLA algorithm converged after  25  iterations
# PLA algorithm converged after  204  iterations
# PLA algorithm converged after  83  iterations
# PLA algorithm converged after  258  iterations
# PLA algorithm converged after  67  iterations
# PLA algorithm converged after  39  iterations
# PLA algorithm converged after  252  iterations
# PLA algorithm converged after  100  iterations
# PLA algorithm converged after  136  iterations
# PLA algorithm converged after  36  iterations
# PLA algorithm converged after  228  iterations
# PLA algorithm converged after  582  iterations
# PLA algorithm converged after  28  iterations
# PLA algorithm converged after  579  iterations
# PLA algorithm converged after  60  iterations
# PLA algorithm converged after  33  iterations
# PLA algorithm converged after  94  iterations
# PLA algorithm converged after  192  iterations
# PLA algorithm converged after  185  iterations
# PLA algorithm converged after  82  iterations
# PLA algorithm converged after  76  iterations
# PLA algorithm converged after  16  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  30  iterations
# PLA algorithm converged after  107  iterations
# PLA algorithm converged after  80  iterations
# PLA algorithm converged after  946  iterations
# PLA algorithm converged after  32  iterations
# PLA algorithm converged after  23  iterations
# PLA algorithm converged after  40  iterations
# PLA algorithm converged after  40  iterations
# PLA algorithm converged after  59  iterations
# PLA algorithm converged after  36  iterations
# PLA algorithm converged after  222  iterations
# PLA algorithm converged after  79  iterations
# PLA algorithm converged after  167  iterations
# PLA algorithm converged after  27  iterations
# PLA algorithm converged after  119  iterations
# PLA algorithm converged after  47  iterations
# PLA algorithm converged after  76  iterations
# PLA algorithm converged after  87  iterations
# PLA algorithm converged after  198  iterations
# PLA algorithm converged after  61  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  248  iterations
# PLA algorithm converged after  34  iterations
# PLA algorithm converged after  752  iterations
# PLA algorithm converged after  188  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  632  iterations
# PLA algorithm converged after  8  iterations
# PLA algorithm converged after  167  iterations
# PLA algorithm converged after  27  iterations
# PLA algorithm converged after  472  iterations
# PLA algorithm converged after  74  iterations
# PLA algorithm converged after  35  iterations
# PLA algorithm converged after  30  iterations
# PLA algorithm converged after  126  iterations
# PLA algorithm converged after  102  iterations
# PLA algorithm converged after  31  iterations
# PLA algorithm converged after  80  iterations
# PLA algorithm converged after  75  iterations
# PLA algorithm converged after  133  iterations
# PLA algorithm converged after  106  iterations
# PLA algorithm converged after  29  iterations
# PLA algorithm converged after  14  iterations
# PLA algorithm converged after  19  iterations
# PLA algorithm converged after  24  iterations
# PLA algorithm converged after  136  iterations
# PLA algorithm converged after  72  iterations
# PLA algorithm converged after  36  iterations
# PLA algorithm converged after  22  iterations
# PLA algorithm converged after  112  iterations
# PLA algorithm converged after  218  iterations
# PLA algorithm converged after  23  iterations
# PLA algorithm converged after  19  iterations
# PLA algorithm converged after  123  iterations
# PLA algorithm converged after  28  iterations
# PLA algorithm converged after  47  iterations
# PLA algorithm converged after  183  iterations
# PLA algorithm converged after  111  iterations
# PLA algorithm converged after  135  iterations
# PLA algorithm converged after  163  iterations
# PLA algorithm converged after  52  iterations
# PLA algorithm converged after  39  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  121  iterations
# PLA algorithm converged after  50  iterations
# PLA algorithm converged after  59  iterations
# PLA algorithm converged after  104  iterations
# PLA algorithm converged after  294  iterations
# PLA algorithm converged after  194  iterations
# PLA algorithm converged after  280  iterations
# PLA algorithm converged after  32  iterations
# PLA algorithm converged after  320  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  143  iterations
# PLA algorithm converged after  62  iterations
# PLA algorithm converged after  43  iterations
# PLA algorithm converged after  94  iterations
# PLA algorithm converged after  692  iterations
# PLA algorithm converged after  77  iterations
# PLA algorithm converged after  26  iterations
# PLA algorithm converged after  33  iterations
# PLA algorithm converged after  175  iterations
# PLA algorithm converged after  223  iterations
# PLA algorithm converged after  120  iterations
# PLA algorithm converged after  53  iterations
# PLA algorithm converged after  50  iterations
# PLA algorithm converged after  43  iterations
# PLA algorithm converged after  50  iterations
# PLA algorithm converged after  92  iterations
# PLA algorithm converged after  18  iterations
# PLA algorithm converged after  68  iterations
# PLA algorithm converged after  74  iterations
# PLA algorithm converged after  162  iterations
# PLA algorithm converged after  142  iterations
# PLA algorithm converged after  83  iterations
# PLA algorithm converged after  100  iterations
# PLA algorithm converged after  53  iterations
# PLA algorithm converged after  100  iterations
# PLA algorithm converged after  37  iterations
# PLA algorithm converged after  42  iterations
# PLA algorithm converged after  82  iterations
# PLA algorithm converged after  41  iterations
# PLA algorithm converged after  75  iterations
# PLA algorithm converged after  748  iterations
# PLA algorithm converged after  77  iterations
# PLA algorithm converged after  45  iterations
# PLA algorithm converged after  7  iterations
# PLA algorithm converged after  10  iterations
# PLA algorithm converged after  96  iterations
# PLA algorithm converged after  49  iterations
# PLA algorithm converged after  4952  iterations
# PLA algorithm converged after  106  iterations
# PLA algorithm converged after  28  iterations
# PLA algorithm converged after  44  iterations
# PLA algorithm converged after  77  iterations
# PLA algorithm converged after  15  iterations
# PLA algorithm converged after  247  iterations
# PLA algorithm converged after  83  iterations
# PLA algorithm converged after  52  iterations
# PLA algorithm converged after  72  iterations
# PLA algorithm converged after  109  iterations
# PLA algorithm converged after  167  iterations
# PLA algorithm converged after  32  iterations
# PLA algorithm converged after  30  iterations
# PLA algorithm converged after  29  iterations
# PLA algorithm converged after  93  iterations
# PLA algorithm converged after  66  iterations
# PLA algorithm converged after  63  iterations
# PLA algorithm converged after  45  iterations
# PLA algorithm converged after  55  iterations
# PLA algorithm converged after  414  iterations
# PLA algorithm converged after  135  iterations
# PLA algorithm converged after  18  iterations
# PLA algorithm converged after  58  iterations
# PLA algorithm converged after  38  iterations
# PLA algorithm converged after  46  iterations
# PLA algorithm converged after  128  iterations
# PLA algorithm converged after  39  iterations
# PLA algorithm converged after  3  iterations
# PLA algorithm converged after  274  iterations
# PLA algorithm converged after  132  iterations
# PLA algorithm converged after  117  iterations
# PLA algorithm converged after  39  iterations
# PLA algorithm converged after  38  iterations
# PLA algorithm converged after  50  iterations
# PLA algorithm converged after  6  iterations
# PLA algorithm converged after  71  iterations
# PLA algorithm converged after  91  iterations
# PLA algorithm converged after  98  iterations
# PLA algorithm converged after  66  iterations
# PLA algorithm converged after  44  iterations
# PLA algorithm converged after  141  iterations
# PLA algorithm converged after  82  iterations
# PLA algorithm converged after  4  iterations
# PLA algorithm converged after  56  iterations
# PLA algorithm converged after  282  iterations
# PLA algorithm converged after  55  iterations
# PLA algorithm converged after  80  iterations
# PLA algorithm converged after  132  iterations
# PLA algorithm converged after  46  iterations
# PLA algorithm converged after  82  iterations
# PLA algorithm converged after  48  iterations
# PLA algorithm converged after  272  iterations
# PLA algorithm converged after  11  iterations
# PLA algorithm converged after  133  iterations
# PLA algorithm converged after  82  iterations
# PLA algorithm converged after  1280  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  22  iterations
# PLA algorithm converged after  90  iterations
# PLA algorithm converged after  11  iterations
# PLA algorithm converged after  95  iterations
# PLA algorithm converged after  147  iterations
# PLA algorithm converged after  85  iterations
# PLA algorithm converged after  682  iterations
# PLA algorithm converged after  70  iterations
# PLA algorithm converged after  43  iterations
# PLA algorithm converged after  131  iterations
# PLA algorithm converged after  144  iterations
# PLA algorithm converged after  37  iterations
# PLA algorithm converged after  123  iterations
# PLA algorithm converged after  90  iterations
# PLA algorithm converged after  62  iterations
# PLA algorithm converged after  312  iterations
# PLA algorithm converged after  26  iterations
# PLA algorithm converged after  44  iterations
# PLA algorithm converged after  25  iterations
# PLA algorithm converged after  53  iterations
# PLA algorithm converged after  73  iterations
# PLA algorithm converged after  158  iterations
# PLA algorithm converged after  155  iterations
# PLA algorithm converged after  147  iterations
# PLA algorithm converged after  127  iterations
# PLA algorithm converged after  70  iterations
# PLA algorithm converged after  156  iterations
# PLA algorithm converged after  115  iterations
# PLA algorithm converged after  19  iterations
# PLA algorithm converged after  31  iterations
# PLA algorithm converged after  37  iterations
# PLA algorithm converged after  43  iterations
# PLA algorithm converged after  319  iterations
# PLA algorithm converged after  52  iterations
# PLA algorithm converged after  75  iterations
# PLA algorithm converged after  96  iterations
# PLA algorithm converged after  405  iterations
# PLA algorithm converged after  196  iterations
# PLA algorithm converged after  63  iterations
# PLA algorithm converged after  63  iterations
# PLA algorithm converged after  104  iterations
# PLA algorithm converged after  23  iterations
# PLA algorithm converged after  177  iterations
# PLA algorithm converged after  79  iterations
# PLA algorithm converged after  34  iterations
# PLA algorithm converged after  42  iterations
# PLA algorithm converged after  70  iterations
# PLA algorithm converged after  73  iterations
# PLA algorithm converged after  170  iterations
# PLA algorithm converged after  12  iterations
# PLA algorithm converged after  105  iterations
# PLA algorithm converged after  80  iterations
# PLA algorithm converged after  82  iterations
# PLA algorithm converged after  65  iterations
# PLA algorithm converged after  22  iterations
# PLA algorithm converged after  66  iterations
# PLA algorithm converged after  20  iterations
# PLA algorithm converged after  33  iterations
# PLA algorithm converged after  105  iterations
# PLA algorithm converged after  26  iterations
# Average number of iterations =  131.128
# Average disagreement probability between f and g =  0.012683999999999964

# %%
trainingSet = DataSet(N=1000, dim=2, lower=-1.0, upper=1.0)
meanIterations, meanDisagreementProb = runPerceptron(np.array([0.0, 0.0, 0.0]), trainingSet, numRuns=1000, maxIterations=1000000)
print('Average number of iterations = ', meanIterations)
print('Average disagreement probability between f and g = ', meanDisagreementProb)
# Out:
# PLA algorithm converged after  319  iterations
# PLA algorithm converged after  493  iterations
# PLA algorithm converged after  399  iterations
# PLA algorithm converged after  373  iterations
# PLA algorithm converged after  610  iterations
# PLA algorithm converged after  396  iterations
# PLA algorithm converged after  345  iterations
# PLA algorithm converged after  843  iterations
# PLA algorithm converged after  1387  iterations
# PLA algorithm converged after  935  iterations
# PLA algorithm converged after  498  iterations
# PLA algorithm converged after  741  iterations
# PLA algorithm converged after  871  iterations
# PLA algorithm converged after  746  iterations
# PLA algorithm converged after  491  iterations
# PLA algorithm converged after  382  iterations
# PLA algorithm converged after  2024  iterations
# PLA algorithm converged after  1236  iterations
# PLA algorithm converged after  182  iterations
# PLA algorithm converged after  90  iterations
# PLA algorithm converged after  266  iterations
# PLA algorithm converged after  1459  iterations
# PLA algorithm converged after  97  iterations
# PLA algorithm converged after  191  iterations
# PLA algorithm converged after  243  iterations
# PLA algorithm converged after  838  iterations
# PLA algorithm converged after  210  iterations
# PLA algorithm converged after  1192  iterations
# PLA algorithm converged after  472  iterations
# PLA algorithm converged after  1258  iterations
# PLA algorithm converged after  26  iterations
# PLA algorithm converged after  1093  iterations
# PLA algorithm converged after  203  iterations
# PLA algorithm converged after  5820  iterations
# PLA algorithm converged after  711  iterations
# PLA algorithm converged after  835  iterations
# PLA algorithm converged after  279  iterations
# PLA algorithm converged after  671  iterations
# PLA algorithm converged after  1359  iterations
# PLA algorithm converged after  377  iterations
# PLA algorithm converged after  2985  iterations
# PLA algorithm converged after  287  iterations
# PLA algorithm converged after  1471  iterations
# PLA algorithm converged after  569  iterations
# PLA algorithm converged after  591  iterations
# PLA algorithm converged after  108  iterations
# PLA algorithm converged after  21  iterations
# PLA algorithm converged after  738  iterations
# PLA algorithm converged after  468  iterations
# PLA algorithm converged after  273  iterations
# PLA algorithm converged after  642  iterations
# PLA algorithm converged after  161  iterations
# PLA algorithm converged after  573  iterations
# PLA algorithm converged after  547  iterations
# PLA algorithm converged after  213  iterations
# PLA algorithm converged after  187  iterations
# PLA algorithm converged after  325  iterations
# PLA algorithm converged after  131  iterations
# PLA algorithm converged after  2094  iterations
# PLA algorithm converged after  626  iterations
# PLA algorithm converged after  1806  iterations
# PLA algorithm converged after  614  iterations
# PLA algorithm converged after  514  iterations
# PLA algorithm converged after  487  iterations
# PLA algorithm converged after  622  iterations
# PLA algorithm converged after  3130  iterations
# PLA algorithm converged after  387  iterations
# PLA algorithm converged after  263  iterations
# PLA algorithm converged after  674  iterations
# PLA algorithm converged after  382  iterations
# PLA algorithm converged after  404  iterations
# PLA algorithm converged after  315  iterations
# PLA algorithm converged after  887  iterations
# PLA algorithm converged after  824  iterations
# PLA algorithm converged after  158  iterations
# PLA algorithm converged after  205  iterations
# PLA algorithm converged after  365  iterations
# PLA algorithm converged after  133  iterations
# PLA algorithm converged after  269  iterations
# PLA algorithm converged after  729  iterations
# PLA algorithm converged after  1505  iterations
# PLA algorithm converged after  414  iterations
# PLA algorithm converged after  678  iterations
# PLA algorithm converged after  1602  iterations
# PLA algorithm converged after  448  iterations
# PLA algorithm converged after  235  iterations
# PLA algorithm converged after  163  iterations
# PLA algorithm converged after  67  iterations
# PLA algorithm converged after  280  iterations
# PLA algorithm converged after  198  iterations
# PLA algorithm converged after  2428  iterations
# PLA algorithm converged after  103  iterations
# PLA algorithm converged after  3352  iterations
# PLA algorithm converged after  768  iterations
# PLA algorithm converged after  310  iterations
# PLA algorithm converged after  605  iterations
# PLA algorithm converged after  288  iterations
# PLA algorithm converged after  200  iterations
# PLA algorithm converged after  170  iterations
# PLA algorithm converged after  790  iterations
# PLA algorithm converged after  920  iterations
# PLA algorithm converged after  452  iterations
# PLA algorithm converged after  345  iterations
# PLA algorithm converged after  608  iterations
# PLA algorithm converged after  1285  iterations
# PLA algorithm converged after  1031  iterations
# PLA algorithm converged after  644  iterations
# PLA algorithm converged after  491  iterations
# PLA algorithm converged after  615  iterations
# PLA algorithm converged after  113  iterations
# PLA algorithm converged after  1011  iterations
# PLA algorithm converged after  1651  iterations
# PLA algorithm converged after  668  iterations
# PLA algorithm converged after  730  iterations
# PLA algorithm converged after  143  iterations
# PLA algorithm converged after  706  iterations
# PLA algorithm converged after  311  iterations
# PLA algorithm converged after  307  iterations
# PLA algorithm converged after  96  iterations
# PLA algorithm converged after  3400  iterations
# PLA algorithm converged after  368  iterations
# PLA algorithm converged after  56  iterations
# PLA algorithm converged after  404  iterations
# PLA algorithm converged after  270  iterations
# PLA algorithm converged after  311  iterations
# PLA algorithm converged after  316  iterations
# PLA algorithm converged after  156  iterations
# PLA algorithm converged after  550  iterations
# PLA algorithm converged after  2261  iterations
# PLA algorithm converged after  378  iterations
# PLA algorithm converged after  1838  iterations
# PLA algorithm converged after  324  iterations
# PLA algorithm converged after  2810  iterations
# PLA algorithm converged after  856  iterations
# PLA algorithm converged after  1262  iterations
# PLA algorithm converged after  543  iterations
# PLA algorithm converged after  394  iterations
# PLA algorithm converged after  230  iterations
# PLA algorithm converged after  329  iterations
# PLA algorithm converged after  580  iterations
# PLA algorithm converged after  301  iterations
# PLA algorithm converged after  103  iterations
# PLA algorithm converged after  764  iterations
# PLA algorithm converged after  160  iterations
# PLA algorithm converged after  1272  iterations
# PLA algorithm converged after  1684  iterations
# PLA algorithm converged after  628  iterations
# PLA algorithm converged after  1106  iterations
# PLA algorithm converged after  411  iterations
# PLA algorithm converged after  730  iterations
# PLA algorithm converged after  3616  iterations
# PLA algorithm converged after  130  iterations
# PLA algorithm converged after  105  iterations
# PLA algorithm converged after  2516  iterations
# PLA algorithm converged after  1935  iterations
# PLA algorithm converged after  222  iterations
# PLA algorithm converged after  174  iterations
# PLA algorithm converged after  1199  iterations
# PLA algorithm converged after  922  iterations
# PLA algorithm converged after  486  iterations
# PLA algorithm converged after  184  iterations
# PLA algorithm converged after  208  iterations
# PLA algorithm converged after  79  iterations
# PLA algorithm converged after  258  iterations
# PLA algorithm converged after  1041  iterations
# PLA algorithm converged after  81  iterations
# PLA algorithm converged after  1184  iterations
# PLA algorithm converged after  1187  iterations
# PLA algorithm converged after  603  iterations
# PLA algorithm converged after  1228  iterations
# PLA algorithm converged after  481  iterations
# PLA algorithm converged after  686  iterations
# PLA algorithm converged after  572  iterations
# PLA algorithm converged after  1411  iterations
# PLA algorithm converged after  332  iterations
# PLA algorithm converged after  137  iterations
# PLA algorithm converged after  2144  iterations
# PLA algorithm converged after  479  iterations
# PLA algorithm converged after  739  iterations
# PLA algorithm converged after  444  iterations
# PLA algorithm converged after  417  iterations
# PLA algorithm converged after  289  iterations
# PLA algorithm converged after  579  iterations
# PLA algorithm converged after  487  iterations
# PLA algorithm converged after  228  iterations
# PLA algorithm converged after  1413  iterations
# PLA algorithm converged after  394  iterations
# PLA algorithm converged after  536  iterations
# PLA algorithm converged after  399  iterations
# PLA algorithm converged after  1697  iterations
# PLA algorithm converged after  802  iterations
# PLA algorithm converged after  153  iterations
# PLA algorithm converged after  601  iterations
# PLA algorithm converged after  13868  iterations
# PLA algorithm converged after  423  iterations
# PLA algorithm converged after  864  iterations
# PLA algorithm converged after  341  iterations
# PLA algorithm converged after  1063  iterations
# PLA algorithm converged after  385  iterations
# PLA algorithm converged after  508  iterations
# PLA algorithm converged after  5492  iterations
# PLA algorithm converged after  871  iterations
# PLA algorithm converged after  206  iterations
# PLA algorithm converged after  1958  iterations
# PLA algorithm converged after  922  iterations
# PLA algorithm converged after  279  iterations
# PLA algorithm converged after  96  iterations
# PLA algorithm converged after  2810  iterations
# PLA algorithm converged after  850  iterations
# PLA algorithm converged after  729  iterations
# PLA algorithm converged after  167  iterations
# PLA algorithm converged after  402  iterations
# PLA algorithm converged after  667  iterations
# PLA algorithm converged after  317  iterations
# PLA algorithm converged after  318  iterations
# PLA algorithm converged after  145  iterations
# PLA algorithm converged after  423  iterations
# PLA algorithm converged after  297  iterations
# PLA algorithm converged after  131  iterations
# PLA algorithm converged after  1864  iterations
# PLA algorithm converged after  569  iterations
# PLA algorithm converged after  288  iterations
# PLA algorithm converged after  756  iterations
# PLA algorithm converged after  554  iterations
# PLA algorithm converged after  193  iterations
# PLA algorithm converged after  426  iterations
# PLA algorithm converged after  598  iterations
# PLA algorithm converged after  770  iterations
# PLA algorithm converged after  55  iterations
# PLA algorithm converged after  5836  iterations
# PLA algorithm converged after  144  iterations
# PLA algorithm converged after  146  iterations
# PLA algorithm converged after  449  iterations
# PLA algorithm converged after  1648  iterations
# PLA algorithm converged after  780  iterations
# PLA algorithm converged after  338  iterations
# PLA algorithm converged after  452  iterations
# PLA algorithm converged after  500  iterations
# PLA algorithm converged after  372  iterations
# PLA algorithm converged after  144  iterations
# PLA algorithm converged after  490  iterations
# PLA algorithm converged after  540  iterations
# PLA algorithm converged after  268  iterations
# PLA algorithm converged after  248  iterations
# PLA algorithm converged after  386  iterations
# PLA algorithm converged after  910  iterations
# PLA algorithm converged after  1452  iterations
# PLA algorithm converged after  289  iterations
# PLA algorithm converged after  12390  iterations
# PLA algorithm converged after  111  iterations
# PLA algorithm converged after  338  iterations
# PLA algorithm converged after  615  iterations
# PLA algorithm converged after  1084  iterations
# PLA algorithm converged after  484  iterations
# PLA algorithm converged after  4960  iterations
# PLA algorithm converged after  602  iterations
# PLA algorithm converged after  640  iterations
# PLA algorithm converged after  178  iterations
# PLA algorithm converged after  732  iterations
# PLA algorithm converged after  874  iterations
# PLA algorithm converged after  462  iterations
# PLA algorithm converged after  374  iterations
# PLA algorithm converged after  89  iterations
# PLA algorithm converged after  129  iterations
# PLA algorithm converged after  562  iterations
# PLA algorithm converged after  391  iterations
# PLA algorithm converged after  422  iterations
# PLA algorithm converged after  550  iterations
# PLA algorithm converged after  101  iterations
# PLA algorithm converged after  4866  iterations
# PLA algorithm converged after  1459  iterations
# PLA algorithm converged after  835  iterations
# PLA algorithm converged after  179  iterations
# PLA algorithm converged after  744  iterations
# PLA algorithm converged after  123  iterations
# PLA algorithm converged after  890  iterations
# PLA algorithm converged after  238  iterations
# PLA algorithm converged after  321  iterations
# PLA algorithm converged after  161  iterations
# PLA algorithm converged after  938  iterations
# PLA algorithm converged after  2092  iterations
# PLA algorithm converged after  1687  iterations
# PLA algorithm converged after  144  iterations
# PLA algorithm converged after  974  iterations
# PLA algorithm converged after  254  iterations
# PLA algorithm converged after  422  iterations
# PLA algorithm converged after  237  iterations
# PLA algorithm converged after  56  iterations
# PLA algorithm converged after  985  iterations
# PLA algorithm converged after  1024  iterations
# PLA algorithm converged after  1049  iterations
# PLA algorithm converged after  378  iterations
# PLA algorithm converged after  967  iterations
# PLA algorithm converged after  466  iterations
# PLA algorithm converged after  369  iterations
# PLA algorithm converged after  336  iterations
# PLA algorithm converged after  1843  iterations
# PLA algorithm converged after  1241  iterations
# PLA algorithm converged after  560  iterations
# PLA algorithm converged after  522  iterations
# PLA algorithm converged after  521  iterations
# PLA algorithm converged after  182  iterations
# PLA algorithm converged after  703  iterations
# PLA algorithm converged after  304  iterations
# PLA algorithm converged after  743  iterations
# PLA algorithm converged after  647  iterations
# PLA algorithm converged after  388  iterations
# PLA algorithm converged after  46066  iterations
# PLA algorithm converged after  2420  iterations
# PLA algorithm converged after  523  iterations
# PLA algorithm converged after  262  iterations
# PLA algorithm converged after  1924  iterations
# PLA algorithm converged after  662  iterations
# PLA algorithm converged after  288  iterations
# PLA algorithm converged after  623  iterations
# PLA algorithm converged after  894  iterations
# PLA algorithm converged after  351  iterations
# PLA algorithm converged after  259  iterations
# PLA algorithm converged after  125  iterations
# PLA algorithm converged after  231  iterations
# PLA algorithm converged after  331  iterations
# PLA algorithm converged after  337  iterations
# PLA algorithm converged after  1933  iterations
# PLA algorithm converged after  767  iterations
# PLA algorithm converged after  1501  iterations
# PLA algorithm converged after  585  iterations
# PLA algorithm converged after  184  iterations
# PLA algorithm converged after  971  iterations
# PLA algorithm converged after  1474  iterations
# PLA algorithm converged after  373  iterations
# PLA algorithm converged after  811  iterations
# PLA algorithm converged after  254  iterations
# PLA algorithm converged after  647  iterations
# PLA algorithm converged after  7788  iterations
# PLA algorithm converged after  741  iterations
# PLA algorithm converged after  173  iterations
# PLA algorithm converged after  803  iterations
# PLA algorithm converged after  307  iterations
# PLA algorithm converged after  460  iterations
# PLA algorithm converged after  170  iterations
# PLA algorithm converged after  2043  iterations
# PLA algorithm converged after  396  iterations
# PLA algorithm converged after  475  iterations
# PLA algorithm converged after  1378  iterations
# PLA algorithm converged after  19712  iterations
# PLA algorithm converged after  1339  iterations
# PLA algorithm converged after  942  iterations
# PLA algorithm converged after  562  iterations
# PLA algorithm converged after  2286  iterations
# PLA algorithm converged after  1369  iterations
# PLA algorithm converged after  173  iterations
# PLA algorithm converged after  172  iterations
# PLA algorithm converged after  449  iterations
# PLA algorithm converged after  817  iterations
# PLA algorithm converged after  492  iterations
# PLA algorithm converged after  471  iterations
# PLA algorithm converged after  277  iterations
# PLA algorithm converged after  517  iterations
# PLA algorithm converged after  423  iterations
# PLA algorithm converged after  361  iterations
# PLA algorithm converged after  828  iterations
# PLA algorithm converged after  258  iterations
# PLA algorithm converged after  171  iterations
# PLA algorithm converged after  2071  iterations
# PLA algorithm converged after  666  iterations
# PLA algorithm converged after  2364  iterations
# PLA algorithm converged after  524  iterations
# PLA algorithm converged after  536  iterations
# PLA algorithm converged after  223  iterations
# PLA algorithm converged after  599  iterations
# PLA algorithm converged after  984  iterations
# PLA algorithm converged after  103  iterations
# PLA algorithm converged after  397  iterations
# PLA algorithm converged after  528  iterations
# PLA algorithm converged after  332  iterations
# PLA algorithm converged after  16794  iterations
# PLA algorithm converged after  1016  iterations
# PLA algorithm converged after  381  iterations
# PLA algorithm converged after  183  iterations
# PLA algorithm converged after  1333  iterations
# PLA algorithm converged after  206  iterations
# PLA algorithm converged after  896  iterations
# PLA algorithm converged after  552  iterations
# PLA algorithm converged after  244  iterations
# PLA algorithm converged after  1481  iterations
# PLA algorithm converged after  1279  iterations
# PLA algorithm converged after  6522  iterations
# PLA algorithm converged after  1402  iterations
# PLA algorithm converged after  1586  iterations
# PLA algorithm converged after  651  iterations
# PLA algorithm converged after  614  iterations
# PLA algorithm converged after  462  iterations
# PLA algorithm converged after  2092  iterations
# PLA algorithm converged after  332  iterations
# PLA algorithm converged after  794  iterations
# PLA algorithm converged after  407  iterations
# PLA algorithm converged after  240  iterations
# PLA algorithm converged after  358  iterations
# PLA algorithm converged after  337  iterations
# PLA algorithm converged after  63  iterations
# PLA algorithm converged after  309  iterations
# PLA algorithm converged after  1033  iterations
# PLA algorithm converged after  545  iterations
# PLA algorithm converged after  234  iterations
# PLA algorithm converged after  243  iterations
# PLA algorithm converged after  36  iterations
# PLA algorithm converged after  340  iterations
# PLA algorithm converged after  248  iterations
# PLA algorithm converged after  108  iterations
# PLA algorithm converged after  512  iterations
# PLA algorithm converged after  2490  iterations
# PLA algorithm converged after  1039  iterations
# PLA algorithm converged after  446  iterations
# PLA algorithm converged after  444  iterations
# PLA algorithm converged after  430  iterations
# PLA algorithm converged after  1057  iterations
# PLA algorithm converged after  853  iterations
# PLA algorithm converged after  334  iterations
# PLA algorithm converged after  399  iterations
# PLA algorithm converged after  179  iterations
# PLA algorithm converged after  1747  iterations
# PLA algorithm converged after  322  iterations
# PLA algorithm converged after  1515  iterations
# PLA algorithm converged after  373  iterations
# PLA algorithm converged after  802  iterations
# PLA algorithm converged after  416  iterations
# PLA algorithm converged after  2842  iterations
# PLA algorithm converged after  333  iterations
# PLA algorithm converged after  1089  iterations
# PLA algorithm converged after  182  iterations
# PLA algorithm converged after  448  iterations
# PLA algorithm converged after  356  iterations
# PLA algorithm converged after  190  iterations
# PLA algorithm converged after  909  iterations
# PLA algorithm converged after  237  iterations
# PLA algorithm converged after  371  iterations
# PLA algorithm converged after  901  iterations
# PLA algorithm converged after  258  iterations
# PLA algorithm converged after  1049  iterations
# PLA algorithm converged after  564  iterations
# PLA algorithm converged after  1338  iterations
# PLA algorithm converged after  315  iterations
# PLA algorithm converged after  1238  iterations
# PLA algorithm converged after  486  iterations
# PLA algorithm converged after  368  iterations
# PLA algorithm converged after  1552  iterations
# PLA algorithm converged after  123  iterations
# PLA algorithm converged after  843  iterations
# PLA algorithm converged after  142  iterations
# PLA algorithm converged after  793  iterations
# PLA algorithm converged after  391  iterations
# PLA algorithm converged after  462  iterations
# PLA algorithm converged after  135  iterations
# PLA algorithm converged after  1124  iterations
# PLA algorithm converged after  649  iterations
# PLA algorithm converged after  302  iterations
# PLA algorithm converged after  516  iterations
# PLA algorithm converged after  329  iterations
# PLA algorithm converged after  240  iterations
# PLA algorithm converged after  365  iterations
# PLA algorithm converged after  256  iterations
# PLA algorithm converged after  235  iterations
# PLA algorithm converged after  876  iterations
# PLA algorithm converged after  715  iterations
# PLA algorithm converged after  731  iterations
# PLA algorithm converged after  1206  iterations
# PLA algorithm converged after  267  iterations
# PLA algorithm converged after  840  iterations
# PLA algorithm converged after  159  iterations
# PLA algorithm converged after  876  iterations
# PLA algorithm converged after  776  iterations
# PLA algorithm converged after  262  iterations
# PLA algorithm converged after  3016  iterations
# PLA algorithm converged after  1884  iterations
# PLA algorithm converged after  498  iterations
# PLA algorithm converged after  192  iterations
# PLA algorithm converged after  341  iterations
# PLA algorithm converged after  77  iterations
# PLA algorithm converged after  391  iterations
# PLA algorithm converged after  793  iterations
# PLA algorithm converged after  321  iterations
# PLA algorithm converged after  688  iterations
# PLA algorithm converged after  1429  iterations
# PLA algorithm converged after  651  iterations
# PLA algorithm converged after  558  iterations
# PLA algorithm converged after  264  iterations
# PLA algorithm converged after  439  iterations
# PLA algorithm converged after  72  iterations
# PLA algorithm converged after  210  iterations
# PLA algorithm converged after  297  iterations
# PLA algorithm converged after  1475  iterations
# PLA algorithm converged after  903  iterations
# PLA algorithm converged after  655  iterations
# PLA algorithm converged after  114  iterations
# PLA algorithm converged after  535  iterations
# PLA algorithm converged after  1445  iterations
# PLA algorithm converged after  468  iterations
# PLA algorithm converged after  1306  iterations
# PLA algorithm converged after  801  iterations
# PLA algorithm converged after  1264  iterations
# PLA algorithm converged after  218  iterations
# PLA algorithm converged after  1100  iterations
# PLA algorithm converged after  1038  iterations
# PLA algorithm converged after  372  iterations
# PLA algorithm converged after  304  iterations
# PLA algorithm converged after  165  iterations
# PLA algorithm converged after  554  iterations
# PLA algorithm converged after  711  iterations
# PLA algorithm converged after  1539  iterations
# PLA algorithm converged after  518  iterations
# PLA algorithm converged after  410  iterations
# PLA algorithm converged after  11892  iterations
# PLA algorithm converged after  3384  iterations
# PLA algorithm converged after  291  iterations
# PLA algorithm converged after  306  iterations
# PLA algorithm converged after  764  iterations
# PLA algorithm converged after  203  iterations
# PLA algorithm converged after  135  iterations
# PLA algorithm converged after  660  iterations
# PLA algorithm converged after  446  iterations
# PLA algorithm converged after  142  iterations
# PLA algorithm converged after  386  iterations
# PLA algorithm converged after  256  iterations
# PLA algorithm converged after  781  iterations
# PLA algorithm converged after  303  iterations
# PLA algorithm converged after  3348  iterations
# PLA algorithm converged after  658  iterations
# PLA algorithm converged after  397  iterations
# PLA algorithm converged after  155  iterations
# PLA algorithm converged after  273  iterations
# PLA algorithm converged after  284  iterations
# PLA algorithm converged after  1372  iterations
# PLA algorithm converged after  236  iterations
# PLA algorithm converged after  412  iterations
# PLA algorithm converged after  399  iterations
# PLA algorithm converged after  654  iterations
# PLA algorithm converged after  68  iterations
# PLA algorithm converged after  1852  iterations
# PLA algorithm converged after  799  iterations
# PLA algorithm converged after  616  iterations
# PLA algorithm converged after  869  iterations
# PLA algorithm converged after  618  iterations
# PLA algorithm converged after  216  iterations
# PLA algorithm converged after  573  iterations
# PLA algorithm converged after  703  iterations
# PLA algorithm converged after  1009  iterations
# PLA algorithm converged after  830  iterations
# PLA algorithm converged after  120  iterations
# PLA algorithm converged after  599  iterations
# PLA algorithm converged after  718  iterations
# PLA algorithm converged after  92  iterations
# PLA algorithm converged after  113  iterations
# PLA algorithm converged after  2189  iterations
# PLA algorithm converged after  4096  iterations
# PLA algorithm converged after  416  iterations
# PLA algorithm converged after  347  iterations
# PLA algorithm converged after  1509  iterations
# PLA algorithm converged after  490  iterations
# PLA algorithm converged after  181  iterations
# PLA algorithm converged after  408  iterations
# PLA algorithm converged after  1132  iterations
# PLA algorithm converged after  67  iterations
# PLA algorithm converged after  502  iterations
# PLA algorithm converged after  400  iterations
# PLA algorithm converged after  907  iterations
# PLA algorithm converged after  1320  iterations
# PLA algorithm converged after  72  iterations
# PLA algorithm converged after  448  iterations
# PLA algorithm converged after  187  iterations
# PLA algorithm converged after  1274  iterations
# PLA algorithm converged after  175  iterations
# PLA algorithm converged after  449  iterations
# PLA algorithm converged after  308  iterations
# PLA algorithm converged after  240  iterations
# PLA algorithm converged after  231  iterations
# PLA algorithm converged after  1334  iterations
# PLA algorithm converged after  310  iterations
# PLA algorithm converged after  386  iterations
# PLA algorithm converged after  643  iterations
# PLA algorithm converged after  502  iterations
# PLA algorithm converged after  538  iterations
# PLA algorithm converged after  1246  iterations
# PLA algorithm converged after  215  iterations
# PLA algorithm converged after  176  iterations
# PLA algorithm converged after  105  iterations
# PLA algorithm converged after  505  iterations
# PLA algorithm converged after  294  iterations
# PLA algorithm converged after  342  iterations
# PLA algorithm converged after  1019  iterations
# PLA algorithm converged after  866  iterations
# PLA algorithm converged after  209  iterations
# PLA algorithm converged after  168  iterations
# PLA algorithm converged after  304  iterations
# PLA algorithm converged after  1092  iterations
# PLA algorithm converged after  456  iterations
# PLA algorithm converged after  92  iterations
# PLA algorithm converged after  802  iterations
# PLA algorithm converged after  894  iterations
# PLA algorithm converged after  307  iterations
# PLA algorithm converged after  986  iterations
# PLA algorithm converged after  182  iterations
# PLA algorithm converged after  221  iterations
# PLA algorithm converged after  2267  iterations
# PLA algorithm converged after  403  iterations
# PLA algorithm converged after  1101  iterations
# PLA algorithm converged after  288  iterations
# PLA algorithm converged after  51292  iterations
# PLA algorithm converged after  379  iterations
# PLA algorithm converged after  90  iterations
# PLA algorithm converged after  1094  iterations
# PLA algorithm converged after  391  iterations
# PLA algorithm converged after  1352  iterations
# PLA algorithm converged after  952  iterations
# PLA algorithm converged after  533  iterations
# PLA algorithm converged after  1205  iterations
# PLA algorithm converged after  478  iterations
# PLA algorithm converged after  302  iterations
# PLA algorithm converged after  386  iterations
# PLA algorithm converged after  246  iterations
# PLA algorithm converged after  747  iterations
# PLA algorithm converged after  242  iterations
# PLA algorithm converged after  47  iterations
# PLA algorithm converged after  824  iterations
# PLA algorithm converged after  798  iterations
# PLA algorithm converged after  314  iterations
# PLA algorithm converged after  286  iterations
# PLA algorithm converged after  27  iterations
# PLA algorithm converged after  1657  iterations
# PLA algorithm converged after  625  iterations
# PLA algorithm converged after  277  iterations
# PLA algorithm converged after  589  iterations
# PLA algorithm converged after  318  iterations
# PLA algorithm converged after  330  iterations
# PLA algorithm converged after  594  iterations
# PLA algorithm converged after  591  iterations
# PLA algorithm converged after  516  iterations
# PLA algorithm converged after  2122  iterations
# PLA algorithm converged after  585  iterations
# PLA algorithm converged after  449  iterations
# PLA algorithm converged after  563  iterations
# PLA algorithm converged after  24  iterations
# PLA algorithm converged after  926  iterations
# PLA algorithm converged after  147  iterations
# PLA algorithm converged after  213  iterations
# PLA algorithm converged after  114  iterations
# PLA algorithm converged after  1501  iterations
# PLA algorithm converged after  234  iterations
# PLA algorithm converged after  562  iterations
# PLA algorithm converged after  816  iterations
# PLA algorithm converged after  227  iterations
# PLA algorithm converged after  607  iterations
# PLA algorithm converged after  160  iterations
# PLA algorithm converged after  238  iterations
# PLA algorithm converged after  85  iterations
# PLA algorithm converged after  1938  iterations
# PLA algorithm converged after  5778  iterations
# PLA algorithm converged after  917  iterations
# PLA algorithm converged after  219  iterations
# PLA algorithm converged after  1938  iterations
# PLA algorithm converged after  2865  iterations
# PLA algorithm converged after  149  iterations
# PLA algorithm converged after  572  iterations
# PLA algorithm converged after  331  iterations
# PLA algorithm converged after  724  iterations
# PLA algorithm converged after  393  iterations
# PLA algorithm converged after  428  iterations
# PLA algorithm converged after  944  iterations
# PLA algorithm converged after  851  iterations
# PLA algorithm converged after  463  iterations
# PLA algorithm converged after  499  iterations
# PLA algorithm converged after  174  iterations
# PLA algorithm converged after  748  iterations
# PLA algorithm converged after  593  iterations
# PLA algorithm converged after  198  iterations
# PLA algorithm converged after  129  iterations
# PLA algorithm converged after  215  iterations
# PLA algorithm converged after  1091  iterations
# PLA algorithm converged after  1392  iterations
# PLA algorithm converged after  2231  iterations
# PLA algorithm converged after  1058  iterations
# PLA algorithm converged after  451  iterations
# PLA algorithm converged after  4334  iterations
# PLA algorithm converged after  339  iterations
# PLA algorithm converged after  804  iterations
# PLA algorithm converged after  571  iterations
# PLA algorithm converged after  233  iterations
# PLA algorithm converged after  177  iterations
# PLA algorithm converged after  121  iterations
# PLA algorithm converged after  1173  iterations
# PLA algorithm converged after  1160  iterations
# PLA algorithm converged after  563  iterations
# PLA algorithm converged after  143  iterations
# PLA algorithm converged after  504  iterations
# PLA algorithm converged after  253  iterations
# PLA algorithm converged after  414  iterations
# PLA algorithm converged after  1871  iterations
# PLA algorithm converged after  539  iterations
# PLA algorithm converged after  225  iterations
# PLA algorithm converged after  311  iterations
# PLA algorithm converged after  437  iterations
# PLA algorithm converged after  744  iterations
# PLA algorithm converged after  1611  iterations
# PLA algorithm converged after  316  iterations
# PLA algorithm converged after  580  iterations
# PLA algorithm converged after  571  iterations
# PLA algorithm converged after  170  iterations
# PLA algorithm converged after  980  iterations
# PLA algorithm converged after  279  iterations
# PLA algorithm converged after  472  iterations
# PLA algorithm converged after  3382  iterations
# PLA algorithm converged after  176  iterations
# PLA algorithm converged after  436  iterations
# PLA algorithm converged after  1861  iterations
# PLA algorithm converged after  552  iterations
# PLA algorithm converged after  3285  iterations
# PLA algorithm converged after  297  iterations
# PLA algorithm converged after  2178  iterations
# PLA algorithm converged after  521  iterations
# PLA algorithm converged after  860  iterations
# PLA algorithm converged after  537  iterations
# PLA algorithm converged after  2077  iterations
# PLA algorithm converged after  1572  iterations
# PLA algorithm converged after  507  iterations
# PLA algorithm converged after  405  iterations
# PLA algorithm converged after  473  iterations
# PLA algorithm converged after  187  iterations
# PLA algorithm converged after  377  iterations
# PLA algorithm converged after  779  iterations
# PLA algorithm converged after  403  iterations
# PLA algorithm converged after  2026  iterations
# PLA algorithm converged after  182  iterations
# PLA algorithm converged after  761  iterations
# PLA algorithm converged after  114  iterations
# PLA algorithm converged after  612  iterations
# PLA algorithm converged after  562  iterations
# PLA algorithm converged after  616  iterations
# PLA algorithm converged after  928  iterations
# PLA algorithm converged after  514  iterations
# PLA algorithm converged after  466  iterations
# PLA algorithm converged after  306  iterations
# PLA algorithm converged after  434  iterations
# PLA algorithm converged after  564  iterations
# PLA algorithm converged after  371  iterations
# PLA algorithm converged after  133  iterations
# PLA algorithm converged after  129  iterations
# PLA algorithm converged after  404  iterations
# PLA algorithm converged after  289  iterations
# PLA algorithm converged after  128  iterations
# PLA algorithm converged after  317  iterations
# PLA algorithm converged after  1989  iterations
# PLA algorithm converged after  498  iterations
# PLA algorithm converged after  314  iterations
# PLA algorithm converged after  270  iterations
# PLA algorithm converged after  129  iterations
# PLA algorithm converged after  537  iterations
# PLA algorithm converged after  413  iterations
# PLA algorithm converged after  1147  iterations
# PLA algorithm converged after  361  iterations
# PLA algorithm converged after  141  iterations
# PLA algorithm converged after  49  iterations
# PLA algorithm converged after  586  iterations
# PLA algorithm converged after  113  iterations
# PLA algorithm converged after  68  iterations
# PLA algorithm converged after  475  iterations
# PLA algorithm converged after  465  iterations
# PLA algorithm converged after  987  iterations
# PLA algorithm converged after  964  iterations
# PLA algorithm converged after  543  iterations
# PLA algorithm converged after  677  iterations
# PLA algorithm converged after  965  iterations
# PLA algorithm converged after  280  iterations
# PLA algorithm converged after  412  iterations
# PLA algorithm converged after  2281  iterations
# PLA algorithm converged after  150  iterations
# PLA algorithm converged after  969  iterations
# PLA algorithm converged after  938  iterations
# PLA algorithm converged after  327  iterations
# PLA algorithm converged after  802  iterations
# PLA algorithm converged after  175  iterations
# PLA algorithm converged after  755  iterations
# PLA algorithm converged after  79  iterations
# PLA algorithm converged after  2250  iterations
# PLA algorithm converged after  716  iterations
# PLA algorithm converged after  682  iterations
# PLA algorithm converged after  65  iterations
# PLA algorithm converged after  1186  iterations
# PLA algorithm converged after  314  iterations
# PLA algorithm converged after  141  iterations
# PLA algorithm converged after  980  iterations
# PLA algorithm converged after  362  iterations
# PLA algorithm converged after  408  iterations
# PLA algorithm converged after  1018  iterations
# PLA algorithm converged after  766  iterations
# PLA algorithm converged after  272  iterations
# PLA algorithm converged after  29  iterations
# PLA algorithm converged after  360  iterations
# PLA algorithm converged after  821  iterations
# PLA algorithm converged after  1058  iterations
# PLA algorithm converged after  97  iterations
# PLA algorithm converged after  320  iterations
# PLA algorithm converged after  1026  iterations
# PLA algorithm converged after  519  iterations
# PLA algorithm converged after  907  iterations
# PLA algorithm converged after  330  iterations
# PLA algorithm converged after  2282  iterations
# PLA algorithm converged after  112  iterations
# PLA algorithm converged after  332  iterations
# PLA algorithm converged after  1243  iterations
# PLA algorithm converged after  830  iterations
# PLA algorithm converged after  1935  iterations
# PLA algorithm converged after  99  iterations
# PLA algorithm converged after  206  iterations
# PLA algorithm converged after  856  iterations
# PLA algorithm converged after  818  iterations
# PLA algorithm converged after  626  iterations
# PLA algorithm converged after  454  iterations
# PLA algorithm converged after  208  iterations
# PLA algorithm converged after  1012  iterations
# PLA algorithm converged after  1398  iterations
# PLA algorithm converged after  419  iterations
# PLA algorithm converged after  326  iterations
# PLA algorithm converged after  2217  iterations
# PLA algorithm converged after  1023  iterations
# PLA algorithm converged after  77  iterations
# PLA algorithm converged after  1495  iterations
# PLA algorithm converged after  506  iterations
# PLA algorithm converged after  138  iterations
# PLA algorithm converged after  758  iterations
# PLA algorithm converged after  266  iterations
# PLA algorithm converged after  3293  iterations
# PLA algorithm converged after  445  iterations
# PLA algorithm converged after  1318  iterations
# PLA algorithm converged after  1254  iterations
# PLA algorithm converged after  178  iterations
# PLA algorithm converged after  70  iterations
# PLA algorithm converged after  394  iterations
# PLA algorithm converged after  608  iterations
# PLA algorithm converged after  35718  iterations
# PLA algorithm converged after  745  iterations
# PLA algorithm converged after  271  iterations
# PLA algorithm converged after  197  iterations
# PLA algorithm converged after  340  iterations
# PLA algorithm converged after  2686  iterations
# PLA algorithm converged after  128  iterations
# PLA algorithm converged after  622  iterations
# PLA algorithm converged after  26842  iterations
# PLA algorithm converged after  418  iterations
# PLA algorithm converged after  1710  iterations
# PLA algorithm converged after  374  iterations
# PLA algorithm converged after  619  iterations
# PLA algorithm converged after  997  iterations
# PLA algorithm converged after  409  iterations
# PLA algorithm converged after  621  iterations
# PLA algorithm converged after  433  iterations
# PLA algorithm converged after  548  iterations
# PLA algorithm converged after  337  iterations
# PLA algorithm converged after  551  iterations
# PLA algorithm converged after  613  iterations
# PLA algorithm converged after  598  iterations
# PLA algorithm converged after  163  iterations
# PLA algorithm converged after  370  iterations
# PLA algorithm converged after  310  iterations
# PLA algorithm converged after  334  iterations
# PLA algorithm converged after  712  iterations
# PLA algorithm converged after  457  iterations
# PLA algorithm converged after  666  iterations
# PLA algorithm converged after  1042  iterations
# PLA algorithm converged after  2593  iterations
# PLA algorithm converged after  537  iterations
# PLA algorithm converged after  639  iterations
# PLA algorithm converged after  302  iterations
# PLA algorithm converged after  785  iterations
# PLA algorithm converged after  760  iterations
# PLA algorithm converged after  1044  iterations
# PLA algorithm converged after  1535  iterations
# PLA algorithm converged after  296  iterations
# PLA algorithm converged after  1515  iterations
# PLA algorithm converged after  452  iterations
# PLA algorithm converged after  6032  iterations
# PLA algorithm converged after  546  iterations
# PLA algorithm converged after  837  iterations
# PLA algorithm converged after  500  iterations
# PLA algorithm converged after  906  iterations
# PLA algorithm converged after  1338  iterations
# PLA algorithm converged after  442  iterations
# PLA algorithm converged after  491  iterations
# PLA algorithm converged after  1679  iterations
# PLA algorithm converged after  1665  iterations
# PLA algorithm converged after  243  iterations
# PLA algorithm converged after  271  iterations
# PLA algorithm converged after  164  iterations
# PLA algorithm converged after  300  iterations
# PLA algorithm converged after  799  iterations
# PLA algorithm converged after  373  iterations
# PLA algorithm converged after  2482  iterations
# PLA algorithm converged after  1364  iterations
# PLA algorithm converged after  218  iterations
# PLA algorithm converged after  455  iterations
# PLA algorithm converged after  195  iterations
# PLA algorithm converged after  296  iterations
# PLA algorithm converged after  534  iterations
# PLA algorithm converged after  2278  iterations
# PLA algorithm converged after  181  iterations
# PLA algorithm converged after  294  iterations
# PLA algorithm converged after  217  iterations
# PLA algorithm converged after  2430  iterations
# PLA algorithm converged after  633  iterations
# PLA algorithm converged after  88  iterations
# PLA algorithm converged after  1553  iterations
# PLA algorithm converged after  234  iterations
# PLA algorithm converged after  486  iterations
# PLA algorithm converged after  207  iterations
# PLA algorithm converged after  955  iterations
# PLA algorithm converged after  286  iterations
# PLA algorithm converged after  2099  iterations
# PLA algorithm converged after  326  iterations
# PLA algorithm converged after  635  iterations
# PLA algorithm converged after  2224  iterations
# PLA algorithm converged after  1831  iterations
# PLA algorithm converged after  653  iterations
# PLA algorithm converged after  1995  iterations
# PLA algorithm converged after  709  iterations
# PLA algorithm converged after  15556  iterations
# PLA algorithm converged after  538  iterations
# PLA algorithm converged after  1139  iterations
# PLA algorithm converged after  1328  iterations
# PLA algorithm converged after  203  iterations
# PLA algorithm converged after  8004  iterations
# PLA algorithm converged after  747  iterations
# PLA algorithm converged after  885  iterations
# PLA algorithm converged after  703  iterations
# PLA algorithm converged after  590  iterations
# PLA algorithm converged after  1287  iterations
# PLA algorithm converged after  98  iterations
# PLA algorithm converged after  338  iterations
# PLA algorithm converged after  10330  iterations
# PLA algorithm converged after  2007  iterations
# PLA algorithm converged after  1196  iterations
# PLA algorithm converged after  341  iterations
# PLA algorithm converged after  735  iterations
# PLA algorithm converged after  497  iterations
# PLA algorithm converged after  686  iterations
# PLA algorithm converged after  368  iterations
# PLA algorithm converged after  97  iterations
# PLA algorithm converged after  713  iterations
# PLA algorithm converged after  1246  iterations
# PLA algorithm converged after  519  iterations
# PLA algorithm converged after  540  iterations
# PLA algorithm converged after  956  iterations
# PLA algorithm converged after  368  iterations
# PLA algorithm converged after  280  iterations
# PLA algorithm converged after  60  iterations
# PLA algorithm converged after  117  iterations
# PLA algorithm converged after  453  iterations
# PLA algorithm converged after  576  iterations
# PLA algorithm converged after  458  iterations
# PLA algorithm converged after  549  iterations
# PLA algorithm converged after  769  iterations
# PLA algorithm converged after  156  iterations
# PLA algorithm converged after  395  iterations
# PLA algorithm converged after  118  iterations
# PLA algorithm converged after  85  iterations
# PLA algorithm converged after  521  iterations
# PLA algorithm converged after  1833  iterations
# PLA algorithm converged after  360  iterations
# PLA algorithm converged after  690  iterations
# PLA algorithm converged after  859  iterations
# PLA algorithm converged after  260  iterations
# PLA algorithm converged after  508  iterations
# PLA algorithm converged after  833  iterations
# PLA algorithm converged after  428  iterations
# PLA algorithm converged after  532  iterations
# PLA algorithm converged after  692  iterations
# PLA algorithm converged after  586  iterations
# PLA algorithm converged after  432  iterations
# PLA algorithm converged after  581  iterations
# PLA algorithm converged after  618  iterations
# PLA algorithm converged after  556  iterations
# PLA algorithm converged after  957  iterations
# PLA algorithm converged after  5248  iterations
# PLA algorithm converged after  307  iterations
# PLA algorithm converged after  490  iterations
# PLA algorithm converged after  427  iterations
# PLA algorithm converged after  538  iterations
# PLA algorithm converged after  520  iterations
# PLA algorithm converged after  404  iterations
# PLA algorithm converged after  2280  iterations
# PLA algorithm converged after  175  iterations
# PLA algorithm converged after  170  iterations
# PLA algorithm converged after  3217  iterations
# PLA algorithm converged after  3827  iterations
# PLA algorithm converged after  511  iterations
# PLA algorithm converged after  1214  iterations
# PLA algorithm converged after  466  iterations
# PLA algorithm converged after  216  iterations
# PLA algorithm converged after  486  iterations
# PLA algorithm converged after  652  iterations
# PLA algorithm converged after  1534  iterations
# PLA algorithm converged after  392  iterations
# PLA algorithm converged after  1038  iterations
# Average number of iterations =  1000.483
# Average disagreement probability between f and g =  0.0014099999999999857
